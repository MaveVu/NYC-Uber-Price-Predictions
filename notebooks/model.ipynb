# %%
from pyspark.sql import SparkSession, functions as F
from pyspark.ml.feature import VectorAssembler
from pyspark.sql.functions import log, monotonically_increasing_id
from pyspark.ml.stat import Correlation
from pyspark.ml.regression import LinearRegression, RandomForestRegressor, GBTRegressor
from pyspark.ml.feature import OneHotEncoder
from pyspark.ml.evaluation import RegressionEvaluator
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
spark = (
    SparkSession.builder.appName("model")
    .config("spark.sql.repl.eagerEval.enabled", True) 
    .config("spark.sql.parquet.cacheMetadata", "true")
    .config("spark.sql.session.timeZone", "Etc/UTC")
    .config("spark.driver.extraJavaOptions", "-XX:+UseCompressedOops") \ 
    .config("spark.executor.extraJavaOptions", "-XX:+UseCompressedOops") \
    .config("spark.executor.memory", "8g") \
    .config("spark.executor.cores", "4") \
    .config("spark.driver.memory", "4g") \
    .getOrCreate()
)
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 24/08/23 12:08:24 WARN Utils: Your hostname, MinhVu resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 24/08/23 12:08:24 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/08/23 12:08:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# #### Reading train data

# %%
train = spark.read.parquet('../data/curated/train_data')

# %% [markdown]
# #### Log-transformation

# %%
min_tmp = train.agg(F.min('tmp')).first()[0]
min_dew = train.agg(F.min('dew')).first()[0]

train = train.withColumn('log_miles', log(F.col('trip_miles') + 1))
train = train.withColumn('log_time', log(F.col('trip_time') + 1))
train = train.withColumn('log_tolls', log(F.col('tolls') + 1))
train = train.withColumn('log_wnd', log(F.col('wnd') + 1))
train = train.withColumn('log_tmp', log(F.col('tmp') - min_tmp + 1))
train = train.withColumn('log_dew', log(F.col('dew') - min_dew + 1))
train = train.withColumn('log_slp', log(F.col('slp') + 1))
train = train.withColumn('log_base_fare', log(F.col('base_passenger_fare') + 1))

# %% [markdown]
# #### Vector of selected features

# %%
features = 'features'
input_cols = ['hour', 'pulocationid', 'dolocationid', 'is_weekend', 'log_miles', 
              'log_time', 'log_tolls', 'log_wnd', 'log_tmp', 'log_dew', 'log_slp']


assembler = VectorAssembler(
    # which column to combine
    inputCols=input_cols, 
    # How should the combined columns be named
    outputCol=features
)

model = assembler.transform(train)

# %% [markdown]
# #### Linear Regression with Lasso regularization

# %%
lm = LinearRegression(
    featuresCol='features', 
    labelCol='log_base_fare',
    elasticNetParam=1
).fit(model)
# Out:
# 24/08/23 12:08:57 WARN Instrumentation: [647b0d1c] regParam is zero, which might cause numerical instability and overfitting.
# 24/08/23 12:09:00 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/08/23 12:09:33 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK

# %%
print(f"RMSE on train data: {lm.summary.rootMeanSquaredError}")
print(f"R2 on train data: {lm.summary.r2}")
# Out:
# RMSE on train data: 0.25411668727313813
# R2 on train data: 0.7885271538245844

# %% [markdown]
# #### Reading test data

# %%
test = spark.read.parquet('../data/curated/test_data')

# %%
min_tmp_test = test.agg(F.min('tmp')).first()[0]
min_dew_test = test.agg(F.min('dew')).first()[0]

test = test.withColumn('log_miles', log(F.col('trip_miles') + 1))
test = test.withColumn('log_time', log(F.col('trip_time') + 1))
test = test.withColumn('log_tolls', log(F.col('tolls') + 1))
test = test.withColumn('log_wnd', log(F.col('wnd') + 1))
test = test.withColumn('log_tmp', log(F.col('tmp') - min_tmp_test + 1))
test = test.withColumn('log_dew', log(F.col('dew') - min_dew_test + 1))
test = test.withColumn('log_slp', log(F.col('slp') + 1))
test = test.withColumn('log_base_fare', log(F.col('base_passenger_fare') + 1))

# %%
test_model = assembler.transform(test)

# %%
predictions_lm = lm.transform(test_model)

rmse_evaluator = RegressionEvaluator(
    labelCol='log_base_fare', predictionCol='prediction', metricName='rmse')
rmse = rmse_evaluator.evaluate(predictions_lm)

r2_evaluator = RegressionEvaluator(
    labelCol='log_base_fare', predictionCol='prediction', metricName='r2')
r2 = r2_evaluator.evaluate(predictions_lm)

print(f"RMSE on test data = {rmse}")
print(f"R2 on test data = {r2}")
# Out:
# [Stage 247:>                (0 + 1) / 1][Stage 250:=============> (11 + 1) / 12]
# RMSE on test data = 0.2697466224952964
# R2 on test data = 0.7790835852393875
# [Stage 247:>                                                        (0 + 1) / 1]

# %% [markdown]
# ### Gradient Boost Tree

# %%
gbt = GBTRegressor(
    featuresCol='features',
    labelCol='log_base_fare',
).fit(model)
# Out:
# 24/08/23 12:11:57 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:11:57 WARN BlockManager: Persisting block rdd_104_6 to disk instead.
# 24/08/23 12:11:57 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:11:57 WARN BlockManager: Persisting block rdd_104_3 to disk instead.
# 24/08/23 12:11:57 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:11:57 WARN BlockManager: Persisting block rdd_104_11 to disk instead.
# 24/08/23 12:11:57 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:11:57 WARN BlockManager: Persisting block rdd_104_5 to disk instead.
# 24/08/23 12:11:57 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:11:57 WARN BlockManager: Persisting block rdd_104_7 to disk instead.
# 24/08/23 12:11:57 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:11:57 WARN BlockManager: Persisting block rdd_104_1 to disk instead.
# 24/08/23 12:11:57 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:11:57 WARN BlockManager: Persisting block rdd_104_10 to disk instead.
# 24/08/23 12:11:57 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:11:57 WARN BlockManager: Persisting block rdd_104_0 to disk instead.
# 24/08/23 12:11:57 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:11:57 WARN BlockManager: Persisting block rdd_104_9 to disk instead.
# 24/08/23 12:12:26 WARN MemoryStore: Not enough space to cache rdd_104_13 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:12:26 WARN MemoryStore: Not enough space to cache rdd_104_12 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:12:26 WARN MemoryStore: Not enough space to cache rdd_104_14 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 28.4 MiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 28.4 MiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:12:27 WARN BlockManager: Persisting block rdd_104_13 to disk instead.
# 24/08/23 12:12:27 WARN BlockManager: Persisting block rdd_104_14 to disk instead.
# 24/08/23 12:12:27 WARN BlockManager: Persisting block rdd_104_12 to disk instead.
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 1026.0 KiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 1026.0 KiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 1026.0 KiB so far)
# 24/08/23 12:12:27 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 1026.0 KiB so far)
# 24/08/23 12:12:34 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:12:36 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:12:37 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:12:37 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:12:37 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:12:42 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:13:02 WARN MemoryStore: Not enough space to cache rdd_104_12 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 28.4 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 28.4 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 28.4 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 28.4 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:16 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:13:33 WARN MemoryStore: Not enough space to cache rdd_104_14 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:13:39 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:13:53 WARN MemoryStore: Not enough space to cache rdd_104_14 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:13:53 WARN MemoryStore: Not enough space to cache rdd_104_12 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:14:01 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:14:16 WARN MemoryStore: Not enough space to cache rdd_104_14 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:14:16 WARN MemoryStore: Not enough space to cache rdd_104_12 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:14:25 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:14:25 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:14:26 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:26 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:26 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:26 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:26 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:26 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:26 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:26 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:26 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:14:41 WARN MemoryStore: Not enough space to cache rdd_104_14 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:14:41 WARN MemoryStore: Not enough space to cache rdd_104_13 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:14:51 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:51 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:51 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:51 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:51 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:51 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:51 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:14:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_0 in memory.
# 24/08/23 12:14:51 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 384.0 B so far)
# 24/08/23 12:14:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_0 in memory.
# 24/08/23 12:14:51 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 384.0 B so far)
# 24/08/23 12:14:52 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 28.4 MiB so far)
# 24/08/23 12:14:52 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 28.4 MiB so far)
# 24/08/23 12:14:52 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:14:52 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 28.4 MiB so far)
# 24/08/23 12:14:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_4 in memory.
# 24/08/23 12:14:52 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 384.0 B so far)
# 24/08/23 12:14:52 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:14:52 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:14:52 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 18.0 MiB so far)
# 24/08/23 12:14:52 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 18.0 MiB so far)
# 24/08/23 12:14:52 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 18.0 MiB so far)
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 1540.2 KiB so far)
# 24/08/23 12:14:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_2 in memory.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_124_2 in memory! (computed 384.0 B so far)
# 24/08/23 12:14:53 WARN BlockManager: Persisting block rdd_124_2 to disk instead.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 2.3 MiB so far)
# 24/08/23 12:14:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_11 in memory.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_124_11 in memory! (computed 384.0 B so far)
# 24/08/23 12:14:53 WARN BlockManager: Persisting block rdd_124_11 to disk instead.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_124_6 in memory! (computed 1035.4 KiB so far)
# 24/08/23 12:14:53 WARN BlockManager: Persisting block rdd_124_6 to disk instead.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_124_10 in memory! (computed 1035.4 KiB so far)
# 24/08/23 12:14:53 WARN BlockManager: Persisting block rdd_124_10 to disk instead.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_124_4 in memory! (computed 8.2 MiB so far)
# 24/08/23 12:14:53 WARN BlockManager: Persisting block rdd_124_4 to disk instead.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 5.3 MiB so far)
# 24/08/23 12:14:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_5 in memory.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_124_5 in memory! (computed 384.0 B so far)
# 24/08/23 12:14:53 WARN BlockManager: Persisting block rdd_124_5 to disk instead.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_124_0 in memory! (computed 19.5 MiB so far)
# 24/08/23 12:14:53 WARN BlockManager: Persisting block rdd_124_0 to disk instead.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 1540.2 KiB so far)
# 24/08/23 12:14:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_7 in memory.
# 24/08/23 12:14:53 WARN MemoryStore: Not enough space to cache rdd_124_7 in memory! (computed 384.0 B so far)
# 24/08/23 12:14:53 WARN BlockManager: Persisting block rdd_124_7 to disk instead.
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 18.0 MiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 12.0 MiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 18.0 MiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 1540.2 KiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_9 in memory.
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_124_9 in memory! (computed 384.0 B so far)
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 2.3 MiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_3 in memory.
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_124_3 in memory! (computed 384.0 B so far)
# 24/08/23 12:14:55 WARN BlockManager: Persisting block rdd_124_9 to disk instead.
# 24/08/23 12:14:55 WARN BlockManager: Persisting block rdd_124_3 to disk instead.
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 18.0 MiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 1540.2 KiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 2.3 MiB so far)
# 24/08/23 12:14:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_8 in memory.
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_124_8 in memory! (computed 384.0 B so far)
# 24/08/23 12:14:55 WARN BlockManager: Persisting block rdd_124_8 to disk instead.
# 24/08/23 12:14:55 WARN MemoryStore: Not enough space to cache rdd_124_1 in memory! (computed 2.4 MiB so far)
# 24/08/23 12:14:55 WARN BlockManager: Persisting block rdd_124_1 to disk instead.
# 24/08/23 12:15:04 WARN MemoryStore: Not enough space to cache rdd_124_10 in memory! (computed 3.7 MiB so far)
# 24/08/23 12:15:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_127_10 in memory.
# 24/08/23 12:15:04 WARN MemoryStore: Not enough space to cache rdd_127_10 in memory! (computed 384.0 B so far)
# 24/08/23 12:15:04 WARN BlockManager: Persisting block rdd_127_10 to disk instead.
# 24/08/23 12:15:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_0 in memory.
# 24/08/23 12:15:04 WARN MemoryStore: Not enough space to cache rdd_124_0 in memory! (computed 384.0 B so far)
# 24/08/23 12:15:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_127_0 in memory.
# 24/08/23 12:15:04 WARN MemoryStore: Not enough space to cache rdd_127_0 in memory! (computed 384.0 B so far)
# 24/08/23 12:15:04 WARN BlockManager: Persisting block rdd_127_0 to disk instead.
# 24/08/23 12:15:04 WARN MemoryStore: Not enough space to cache rdd_124_6 in memory! (computed 1035.4 KiB so far)
# 24/08/23 12:15:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_127_6 in memory.
# 24/08/23 12:15:04 WARN MemoryStore: Not enough space to cache rdd_127_6 in memory! (computed 384.0 B so far)
# 24/08/23 12:15:04 WARN BlockManager: Persisting block rdd_127_6 to disk instead.
# 24/08/23 12:15:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_2 in memory.
# 24/08/23 12:15:04 WARN MemoryStore: Not enough space to cache rdd_124_2 in memory! (computed 384.0 B so far)
# 24/08/23 12:15:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_127_2 in memory.
# 24/08/23 12:15:04 WARN MemoryStore: Not enough space to cache rdd_127_2 in memory! (computed 384.0 B so far)
# 24/08/23 12:15:04 WARN BlockManager: Persisting block rdd_127_2 to disk instead.
# 24/08/23 12:15:04 WARN MemoryStore: Not enough space to cache rdd_124_4 in memory! (computed 3.7 MiB so far)
# 24/08/23 12:15:04 WARN MemoryStore: Not enough space to cache rdd_127_4 in memory! (computed 1024.6 KiB so far)
# 24/08/23 12:15:04 WARN BlockManager: Persisting block rdd_127_4 to disk instead.
# 24/08/23 12:15:05 WARN MemoryStore: Not enough space to cache rdd_124_11 in memory! (computed 19.5 MiB so far)
# 24/08/23 12:15:06 WARN MemoryStore: Not enough space to cache rdd_124_9 in memory! (computed 8.2 MiB so far)
# 24/08/23 12:15:06 WARN MemoryStore: Not enough space to cache rdd_124_1 in memory! (computed 5.5 MiB so far)
# 24/08/23 12:15:06 WARN MemoryStore: Not enough space to cache rdd_124_7 in memory! (computed 43.9 MiB so far)
# 24/08/23 12:15:06 WARN MemoryStore: Not enough space to cache rdd_127_9 in memory! (computed 1024.6 KiB so far)
# 24/08/23 12:15:06 WARN BlockManager: Persisting block rdd_127_9 to disk instead.
# 24/08/23 12:15:06 WARN MemoryStore: Not enough space to cache rdd_124_3 in memory! (computed 8.2 MiB so far)
# 24/08/23 12:15:06 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_127_3 in memory.
# 24/08/23 12:15:06 WARN MemoryStore: Not enough space to cache rdd_127_3 in memory! (computed 384.0 B so far)
# 24/08/23 12:15:06 WARN BlockManager: Persisting block rdd_127_3 to disk instead.
# 24/08/23 12:15:06 WARN MemoryStore: Not enough space to cache rdd_124_8 in memory! (computed 13.0 MiB so far)
# 24/08/23 12:15:06 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_127_8 in memory.
# 24/08/23 12:15:06 WARN MemoryStore: Not enough space to cache rdd_127_8 in memory! (computed 384.0 B so far)
# 24/08/23 12:15:06 WARN BlockManager: Persisting block rdd_127_8 to disk instead.
# 24/08/23 12:15:06 WARN MemoryStore: Not enough space to cache rdd_127_1 in memory! (computed 1537.3 KiB so far)
# 24/08/23 12:15:06 WARN BlockManager: Persisting block rdd_127_1 to disk instead.
# 24/08/23 12:15:06 WARN MemoryStore: Not enough space to cache rdd_127_7 in memory! (computed 1537.3 KiB so far)
# 24/08/23 12:15:06 WARN BlockManager: Persisting block rdd_127_7 to disk instead.
# 24/08/23 12:15:09 WARN MemoryStore: Not enough space to cache rdd_127_11 in memory! (computed 64.8 MiB so far)
# 24/08/23 12:15:09 WARN BlockManager: Persisting block rdd_127_11 to disk instead.
# 24/08/23 12:15:15 WARN MemoryStore: Not enough space to cache rdd_127_5 in memory! (computed 99.2 MiB so far)
# 24/08/23 12:15:15 WARN BlockManager: Persisting block rdd_127_5 to disk instead.
# 24/08/23 12:15:22 WARN MemoryStore: Not enough space to cache rdd_127_7 in memory! (computed 6.2 MiB so far)
# 24/08/23 12:15:22 WARN MemoryStore: Not enough space to cache rdd_127_4 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:15:22 WARN MemoryStore: Not enough space to cache rdd_127_0 in memory! (computed 2.7 MiB so far)
# 24/08/23 12:15:22 WARN MemoryStore: Not enough space to cache rdd_127_6 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:15:22 WARN MemoryStore: Not enough space to cache rdd_127_2 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:15:22 WARN MemoryStore: Not enough space to cache rdd_127_10 in memory! (computed 43.2 MiB so far)
# 24/08/23 12:15:27 WARN MemoryStore: Not enough space to cache rdd_127_11 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:15:30 WARN MemoryStore: Not enough space to cache rdd_127_1 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:15:31 WARN MemoryStore: Not enough space to cache rdd_127_5 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:15:31 WARN MemoryStore: Not enough space to cache rdd_127_3 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:15:31 WARN MemoryStore: Not enough space to cache rdd_127_8 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:15:31 WARN MemoryStore: Not enough space to cache rdd_127_9 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:15:44 WARN MemoryStore: Not enough space to cache rdd_124_13 in memory! (computed 156.0 MiB so far)
# 24/08/23 12:15:44 WARN BlockManager: Persisting block rdd_124_13 to disk instead.
# 24/08/23 12:15:50 WARN MemoryStore: Not enough space to cache rdd_127_14 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:15:50 WARN BlockManager: Persisting block rdd_127_14 to disk instead.
# 24/08/23 12:15:50 WARN MemoryStore: Not enough space to cache rdd_127_12 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:15:50 WARN BlockManager: Persisting block rdd_127_12 to disk instead.
# 24/08/23 12:15:50 WARN MemoryStore: Not enough space to cache rdd_124_13 in memory! (computed 65.8 MiB so far)
# 24/08/23 12:15:50 WARN MemoryStore: Not enough space to cache rdd_127_13 in memory! (computed 16.2 MiB so far)
# 24/08/23 12:15:50 WARN BlockManager: Persisting block rdd_127_13 to disk instead.
# 24/08/23 12:16:02 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:16:02 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:16:02 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:16:02 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:16:02 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:16:05 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:16:05 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:16:05 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:16:07 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:16:09 WARN MemoryStore: Not enough space to cache rdd_127_10 in memory! (computed 64.8 MiB so far)
# 24/08/23 12:16:09 WARN MemoryStore: Not enough space to cache rdd_127_0 in memory! (computed 43.2 MiB so far)
# 24/08/23 12:16:09 WARN MemoryStore: Not enough space to cache rdd_127_3 in memory! (computed 43.2 MiB so far)
# 24/08/23 12:16:09 WARN MemoryStore: Not enough space to cache rdd_127_2 in memory! (computed 43.2 MiB so far)
# 24/08/23 12:16:09 WARN MemoryStore: Not enough space to cache rdd_127_11 in memory! (computed 64.8 MiB so far)
# 24/08/23 12:16:09 WARN MemoryStore: Not enough space to cache rdd_127_7 in memory! (computed 64.8 MiB so far)
# 24/08/23 12:16:09 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:16:10 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:16:12 WARN MemoryStore: Not enough space to cache rdd_127_5 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:16:12 WARN MemoryStore: Not enough space to cache rdd_127_9 in memory! (computed 64.8 MiB so far)
# 24/08/23 12:16:12 WARN MemoryStore: Not enough space to cache rdd_127_6 in memory! (computed 99.2 MiB so far)
# 24/08/23 12:16:29 WARN MemoryStore: Not enough space to cache rdd_104_14 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:16:30 WARN MemoryStore: Not enough space to cache rdd_104_13 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:16:43 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:16:43 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:16:43 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:16:43 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:16:43 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:16:43 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:16:44 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_127_9 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_127_7 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_127_0 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_127_11 in memory! (computed 10.8 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_127_2 in memory! (computed 6.2 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_127_1 in memory! (computed 43.2 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_127_3 in memory! (computed 43.2 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_127_6 in memory! (computed 43.2 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:16:46 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:16:47 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:17:03 WARN MemoryStore: Not enough space to cache rdd_127_15 in memory! (computed 64.8 MiB so far)
# 24/08/23 12:17:08 WARN MemoryStore: Not enough space to cache rdd_127_14 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:17:14 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:17:14 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:17:14 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:17:14 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:17:14 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:17:15 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:17:18 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 144.4 MiB so far)
# 24/08/23 12:17:18 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:17:18 WARN MemoryStore: Not enough space to cache rdd_127_6 in memory! (computed 43.2 MiB so far)
# 24/08/23 12:17:18 WARN MemoryStore: Not enough space to cache rdd_127_9 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:17:19 WARN MemoryStore: Not enough space to cache rdd_127_10 in memory! (computed 10.8 MiB so far)
# 24/08/23 12:17:19 WARN MemoryStore: Not enough space to cache rdd_127_3 in memory! (computed 10.8 MiB so far)
# 24/08/23 12:17:19 WARN MemoryStore: Not enough space to cache rdd_127_0 in memory! (computed 64.8 MiB so far)
# 24/08/23 12:17:19 WARN MemoryStore: Not enough space to cache rdd_127_4 in memory! (computed 64.8 MiB so far)
# 24/08/23 12:17:19 WARN MemoryStore: Not enough space to cache rdd_127_8 in memory! (computed 43.2 MiB so far)
# 24/08/23 12:17:19 WARN MemoryStore: Not enough space to cache rdd_127_11 in memory! (computed 64.8 MiB so far)
# 24/08/23 12:17:19 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:17:19 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:17:21 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:17:39 WARN MemoryStore: Not enough space to cache rdd_104_13 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:17:42 WARN MemoryStore: Not enough space to cache rdd_104_14 in memory! (computed 346.2 MiB so far)
# 24/08/23 12:17:52 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:17:52 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:17:52 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:17:52 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:17:52 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:17:56 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:17:56 WARN MemoryStore: Not enough space to cache rdd_127_7 in memory! (computed 16.2 MiB so far)
# 24/08/23 12:17:56 WARN MemoryStore: Not enough space to cache rdd_127_2 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:17:56 WARN MemoryStore: Not enough space to cache rdd_127_6 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:17:56 WARN MemoryStore: Not enough space to cache rdd_127_0 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:17:56 WARN MemoryStore: Not enough space to cache rdd_127_8 in memory! (computed 10.8 MiB so far)
# 24/08/23 12:17:57 WARN MemoryStore: Not enough space to cache rdd_127_1 in memory! (computed 24.3 MiB so far)
# 24/08/23 12:17:57 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:17:59 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:17:59 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:17:59 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:17:59 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:17:59 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 227.2 MiB so far)
# 24/08/23 12:18:02 WARN MemoryStore: Not enough space to cache rdd_127_9 in memory! (computed 99.2 MiB so far)
# 24/08/23 12:18:02 WARN MemoryStore: Not enough space to cache rdd_127_3 in memory! (computed 99.2 MiB so far)
# 24/08/23 12:18:02 WARN MemoryStore: Not enough space to cache rdd_127_10 in memory! (computed 99.2 MiB so far)
# 24/08/23 12:18:02 WARN MemoryStore: Not enough space to cache rdd_127_11 in memory! (computed 99.2 MiB so far)
# 24/08/23 12:18:06 WARN MemoryStore: Not enough space to cache rdd_127_4 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:18:06 WARN MemoryStore: Not enough space to cache rdd_127_5 in memory! (computed 172.8 MiB so far)
# 24/08/23 12:18:28 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 42.8 MiB so far)
# 24/08/23 12:18:28 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 1540.2 KiB so far)
# 24/08/23 12:18:28 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_11 in memory.
# 24/08/23 12:18:28 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 2.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_3 in memory.
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 3.5 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 3.5 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 2.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 2.3 MiB so far)
# 24/08/23 12:18:31 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_7 in memory.
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:31 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_1 in memory.
# 24/08/23 12:18:31 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:32 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:18:32 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:18:32 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:18:32 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 64.2 MiB so far)
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 3.5 MiB so far)
# 24/08/23 12:18:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_4 in memory.
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_124_4 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_146_4 in memory.
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_146_4 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:34 WARN BlockManager: Persisting block rdd_146_4 to disk instead.
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 5.3 MiB so far)
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_124_2 in memory! (computed 2.4 MiB so far)
# 24/08/23 12:18:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_146_2 in memory.
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_146_2 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:34 WARN BlockManager: Persisting block rdd_146_2 to disk instead.
# 24/08/23 12:18:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_8 in memory.
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_124_8 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_146_8 in memory.
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_146_8 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:34 WARN BlockManager: Persisting block rdd_146_8 to disk instead.
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_124_0 in memory! (computed 3.7 MiB so far)
# 24/08/23 12:18:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_146_0 in memory.
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_146_0 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:34 WARN BlockManager: Persisting block rdd_146_0 to disk instead.
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_124_11 in memory! (computed 104.0 MiB so far)
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_124_1 in memory! (computed 43.9 MiB so far)
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_124_3 in memory! (computed 43.9 MiB so far)
# 24/08/23 12:18:34 WARN MemoryStore: Not enough space to cache rdd_124_7 in memory! (computed 43.9 MiB so far)
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_146_11 in memory! (computed 3.7 MiB so far)
# 24/08/23 12:18:35 WARN BlockManager: Persisting block rdd_146_11 to disk instead.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_146_1 in memory! (computed 3.7 MiB so far)
# 24/08/23 12:18:35 WARN BlockManager: Persisting block rdd_146_1 to disk instead.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_6 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_6 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_124_6 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_146_6 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_146_6 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN BlockManager: Persisting block rdd_146_6 to disk instead.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_146_3 in memory! (computed 3.7 MiB so far)
# 24/08/23 12:18:35 WARN BlockManager: Persisting block rdd_146_3 to disk instead.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_146_7 in memory! (computed 3.7 MiB so far)
# 24/08/23 12:18:35 WARN BlockManager: Persisting block rdd_146_7 to disk instead.
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_5 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 96.3 MiB so far)
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_9 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_104_10 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_9 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_124_9 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_146_9 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_146_9 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN BlockManager: Persisting block rdd_146_9 to disk instead.
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_10 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_124_10 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_146_10 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_146_10 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN BlockManager: Persisting block rdd_146_10 to disk instead.
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_124_5 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_124_5 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_146_5 in memory.
# 24/08/23 12:18:35 WARN MemoryStore: Not enough space to cache rdd_146_5 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:35 WARN BlockManager: Persisting block rdd_146_5 to disk instead.
# 24/08/23 12:18:48 WARN MemoryStore: Not enough space to cache rdd_146_11 in memory! (computed 104.0 MiB so far)
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_146_8 in memory! (computed 29.2 MiB so far)
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_146_3 in memory! (computed 43.9 MiB so far)
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_149_11 in memory! (computed 4.0 MiB so far)
# 24/08/23 12:18:49 WARN BlockManager: Persisting block rdd_149_11 to disk instead.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_149_8 in memory! (computed 2.7 MiB so far)
# 24/08/23 12:18:49 WARN BlockManager: Persisting block rdd_149_8 to disk instead.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_146_1 in memory! (computed 43.9 MiB so far)
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_146_5 in memory! (computed 1035.4 KiB so far)
# 24/08/23 12:18:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_149_5 in memory.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_146_4 in memory! (computed 13.0 MiB so far)
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_149_5 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:49 WARN BlockManager: Persisting block rdd_149_5 to disk instead.
# 24/08/23 12:18:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_149_4 in memory.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_149_4 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:49 WARN BlockManager: Persisting block rdd_149_4 to disk instead.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_149_3 in memory! (computed 1537.3 KiB so far)
# 24/08/23 12:18:49 WARN BlockManager: Persisting block rdd_149_3 to disk instead.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_146_2 in memory! (computed 65.8 MiB so far)
# 24/08/23 12:18:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_149_2 in memory.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_149_2 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:49 WARN BlockManager: Persisting block rdd_149_2 to disk instead.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_146_0 in memory! (computed 43.9 MiB so far)
# 24/08/23 12:18:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_149_0 in memory.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_149_0 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:49 WARN BlockManager: Persisting block rdd_149_0 to disk instead.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_146_6 in memory! (computed 1035.4 KiB so far)
# 24/08/23 12:18:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_149_6 in memory.
# 24/08/23 12:18:49 WARN MemoryStore: Not enough space to cache rdd_149_6 in memory! (computed 384.0 B so far)
# 24/08/23 12:18:49 WARN BlockManager: Persisting block rdd_149_6 to disk instead.
# ...
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_520_4 in memory! (computed 104.0 MiB so far)
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_520_7 in memory! (computed 65.8 MiB so far)
# 24/08/23 13:24:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_523_7 in memory.
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_523_7 in memory! (computed 384.0 B so far)
# 24/08/23 13:24:53 WARN BlockManager: Persisting block rdd_523_7 to disk instead.
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_520_9 in memory! (computed 19.5 MiB so far)
# 24/08/23 13:24:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_520_6 in memory.
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_520_8 in memory! (computed 1663.4 KiB so far)
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_520_6 in memory! (computed 384.0 B so far)
# 24/08/23 13:24:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_523_8 in memory.
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_523_8 in memory! (computed 384.0 B so far)
# 24/08/23 13:24:53 WARN BlockManager: Persisting block rdd_523_8 to disk instead.
# 24/08/23 13:24:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_523_6 in memory.
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_523_6 in memory! (computed 384.0 B so far)
# 24/08/23 13:24:53 WARN BlockManager: Persisting block rdd_523_6 to disk instead.
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_520_0 in memory! (computed 43.9 MiB so far)
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_523_2 in memory! (computed 4.0 MiB so far)
# 24/08/23 13:24:53 WARN BlockManager: Persisting block rdd_523_2 to disk instead.
# 24/08/23 13:24:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_520_10 in memory.
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_520_10 in memory! (computed 384.0 B so far)
# 24/08/23 13:24:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_523_10 in memory.
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_523_10 in memory! (computed 384.0 B so far)
# 24/08/23 13:24:53 WARN BlockManager: Persisting block rdd_523_10 to disk instead.
# 24/08/23 13:24:53 WARN MemoryStore: Not enough space to cache rdd_523_9 in memory! (computed 2.7 MiB so far)
# 24/08/23 13:24:53 WARN BlockManager: Persisting block rdd_523_9 to disk instead.
# 24/08/23 13:24:54 WARN MemoryStore: Not enough space to cache rdd_523_0 in memory! (computed 10.8 MiB so far)
# 24/08/23 13:24:54 WARN BlockManager: Persisting block rdd_523_0 to disk instead.
# 24/08/23 13:24:54 WARN MemoryStore: Not enough space to cache rdd_520_1 in memory! (computed 19.5 MiB so far)
# 24/08/23 13:25:19 WARN MemoryStore: Not enough space to cache rdd_523_3 in memory! (computed 99.2 MiB so far)
# 24/08/23 13:25:19 WARN MemoryStore: Not enough space to cache rdd_523_9 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:25:19 WARN MemoryStore: Not enough space to cache rdd_523_8 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:25:19 WARN MemoryStore: Not enough space to cache rdd_523_7 in memory! (computed 99.2 MiB so far)
# 24/08/23 13:25:19 WARN MemoryStore: Not enough space to cache rdd_523_0 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:25:42 WARN MemoryStore: Not enough space to cache rdd_498_12 in memory! (computed 104.0 MiB so far)
# 24/08/23 13:25:42 WARN MemoryStore: Not enough space to cache rdd_104_15 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:25:42 WARN MemoryStore: Not enough space to cache rdd_104_15 in memory! (computed 12.0 MiB so far)
# 24/08/23 13:25:42 WARN MemoryStore: Not enough space to cache rdd_104_15 in memory! (computed 3.5 MiB so far)
# 24/08/23 13:25:42 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_498_15 in memory.
# 24/08/23 13:25:42 WARN MemoryStore: Not enough space to cache rdd_498_15 in memory! (computed 384.0 B so far)
# 24/08/23 13:25:42 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_520_15 in memory.
# 24/08/23 13:25:42 WARN MemoryStore: Not enough space to cache rdd_520_15 in memory! (computed 384.0 B so far)
# 24/08/23 13:25:42 WARN BlockManager: Persisting block rdd_520_15 to disk instead.
# 24/08/23 13:25:42 WARN MemoryStore: Not enough space to cache rdd_520_12 in memory! (computed 29.2 MiB so far)
# 24/08/23 13:25:42 WARN BlockManager: Persisting block rdd_520_12 to disk instead.
# 24/08/23 13:25:43 WARN MemoryStore: Not enough space to cache rdd_498_14 in memory! (computed 156.0 MiB so far)
# 24/08/23 13:25:43 WARN MemoryStore: Not enough space to cache rdd_520_13 in memory! (computed 43.9 MiB so far)
# 24/08/23 13:25:43 WARN BlockManager: Persisting block rdd_520_13 to disk instead.
# 24/08/23 13:25:43 WARN MemoryStore: Not enough space to cache rdd_520_14 in memory! (computed 29.2 MiB so far)
# 24/08/23 13:25:43 WARN BlockManager: Persisting block rdd_520_14 to disk instead.
# 24/08/23 13:25:50 WARN MemoryStore: Not enough space to cache rdd_520_12 in memory! (computed 104.0 MiB so far)
# 24/08/23 13:25:50 WARN MemoryStore: Not enough space to cache rdd_520_14 in memory! (computed 104.0 MiB so far)
# 24/08/23 13:25:50 WARN MemoryStore: Not enough space to cache rdd_523_12 in memory! (computed 16.2 MiB so far)
# 24/08/23 13:25:50 WARN BlockManager: Persisting block rdd_523_12 to disk instead.
# 24/08/23 13:25:50 WARN MemoryStore: Not enough space to cache rdd_523_14 in memory! (computed 6.2 MiB so far)
# 24/08/23 13:25:50 WARN BlockManager: Persisting block rdd_523_14 to disk instead.
# 24/08/23 13:25:50 WARN MemoryStore: Not enough space to cache rdd_523_13 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:25:50 WARN BlockManager: Persisting block rdd_523_13 to disk instead.
# 24/08/23 13:25:50 WARN MemoryStore: Not enough space to cache rdd_520_15 in memory! (computed 104.0 MiB so far)
# 24/08/23 13:25:50 WARN MemoryStore: Not enough space to cache rdd_523_15 in memory! (computed 4.0 MiB so far)
# 24/08/23 13:25:50 WARN BlockManager: Persisting block rdd_523_15 to disk instead.
# 24/08/23 13:26:01 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:26:01 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:26:01 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:26:01 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:26:01 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:26:05 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:26:05 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:26:05 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:26:06 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:26:08 WARN MemoryStore: Not enough space to cache rdd_523_11 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:26:09 WARN MemoryStore: Not enough space to cache rdd_523_3 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:26:09 WARN MemoryStore: Not enough space to cache rdd_523_2 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:26:09 WARN MemoryStore: Not enough space to cache rdd_523_10 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:26:09 WARN MemoryStore: Not enough space to cache rdd_523_0 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:26:09 WARN MemoryStore: Not enough space to cache rdd_523_4 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:26:09 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:26:09 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:26:09 WARN MemoryStore: Not enough space to cache rdd_523_5 in memory! (computed 99.2 MiB so far)
# 24/08/23 13:26:17 WARN MemoryStore: Not enough space to cache rdd_523_8 in memory! (computed 16.2 MiB so far)
# 24/08/23 13:26:38 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 42.8 MiB so far)
# 24/08/23 13:26:38 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:26:38 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:26:41 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:26:41 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:26:42 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 144.4 MiB so far)
# 24/08/23 13:26:45 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 144.4 MiB so far)
# 24/08/23 13:26:45 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:26:45 WARN MemoryStore: Not enough space to cache rdd_523_9 in memory! (computed 6.2 MiB so far)
# 24/08/23 13:26:45 WARN MemoryStore: Not enough space to cache rdd_523_7 in memory! (computed 2.7 MiB so far)
# 24/08/23 13:26:45 WARN MemoryStore: Not enough space to cache rdd_523_10 in memory! (computed 24.3 MiB so far)
# 24/08/23 13:26:45 WARN MemoryStore: Not enough space to cache rdd_523_5 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:26:45 WARN MemoryStore: Not enough space to cache rdd_523_11 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:26:45 WARN MemoryStore: Not enough space to cache rdd_523_0 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:26:45 WARN MemoryStore: Not enough space to cache rdd_523_6 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:26:45 WARN MemoryStore: Not enough space to cache rdd_523_3 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:26:46 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:26:46 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:26:46 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:26:46 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:27:09 WARN MemoryStore: Not enough space to cache rdd_523_12 in memory! (computed 172.8 MiB so far)
# 24/08/23 13:27:09 WARN MemoryStore: Not enough space to cache rdd_523_14 in memory! (computed 172.8 MiB so far)
# 24/08/23 13:27:09 WARN MemoryStore: Not enough space to cache rdd_523_13 in memory! (computed 172.8 MiB so far)
# 24/08/23 13:27:14 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 42.8 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:15 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:22 WARN MemoryStore: Not enough space to cache rdd_523_9 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:22 WARN MemoryStore: Not enough space to cache rdd_523_8 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:22 WARN MemoryStore: Not enough space to cache rdd_523_6 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:22 WARN MemoryStore: Not enough space to cache rdd_523_0 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:22 WARN MemoryStore: Not enough space to cache rdd_523_2 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:22 WARN MemoryStore: Not enough space to cache rdd_523_11 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:22 WARN MemoryStore: Not enough space to cache rdd_523_1 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:22 WARN MemoryStore: Not enough space to cache rdd_523_3 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:22 WARN MemoryStore: Not enough space to cache rdd_523_4 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:22 WARN MemoryStore: Not enough space to cache rdd_523_5 in memory! (computed 99.2 MiB so far)
# 24/08/23 13:27:39 WARN MemoryStore: Not enough space to cache rdd_523_15 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:49 WARN MemoryStore: Not enough space to cache rdd_104_7 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:27:49 WARN MemoryStore: Not enough space to cache rdd_104_6 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:27:49 WARN MemoryStore: Not enough space to cache rdd_104_4 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:27:49 WARN MemoryStore: Not enough space to cache rdd_104_2 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:27:49 WARN MemoryStore: Not enough space to cache rdd_104_10 in memory! (computed 64.2 MiB so far)
# 24/08/23 13:27:52 WARN MemoryStore: Not enough space to cache rdd_104_8 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:52 WARN MemoryStore: Not enough space to cache rdd_104_9 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:52 WARN MemoryStore: Not enough space to cache rdd_104_0 in memory! (computed 96.3 MiB so far)
# 24/08/23 13:27:53 WARN MemoryStore: Not enough space to cache rdd_104_1 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:27:53 WARN MemoryStore: Not enough space to cache rdd_523_7 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:56 WARN MemoryStore: Not enough space to cache rdd_523_8 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:27:56 WARN MemoryStore: Not enough space to cache rdd_523_0 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:27:56 WARN MemoryStore: Not enough space to cache rdd_523_9 in memory! (computed 43.2 MiB so far)
# 24/08/23 13:27:56 WARN MemoryStore: Not enough space to cache rdd_523_2 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:56 WARN MemoryStore: Not enough space to cache rdd_523_6 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:56 WARN MemoryStore: Not enough space to cache rdd_104_3 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:27:56 WARN MemoryStore: Not enough space to cache rdd_104_11 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:27:56 WARN MemoryStore: Not enough space to cache rdd_104_5 in memory! (computed 227.2 MiB so far)
# 24/08/23 13:27:59 WARN MemoryStore: Not enough space to cache rdd_523_11 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:27:59 WARN MemoryStore: Not enough space to cache rdd_523_5 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:28:16 WARN MemoryStore: Not enough space to cache rdd_523_15 in memory! (computed 64.8 MiB so far)
# 24/08/23 13:28:20 WARN MemoryStore: Not enough space to cache rdd_523_14 in memory! (computed 172.8 MiB so far)

# %%
predictions = gbt.transform(model)
evaluator_rmse = RegressionEvaluator(labelCol="log_base_fare", predictionCol="prediction", metricName="rmse")
evaluator_r2 = RegressionEvaluator(labelCol="log_base_fare", predictionCol="prediction", metricName="r2")

rmse = evaluator_rmse.evaluate(predictions)
r2 = evaluator_r2.evaluate(predictions)

print(f"RMSE on train data = {rmse}")
print(f"R2 on train data = {r2}")
# Out:
# [Stage 223:============================================>          (13 + 3) / 16]
# RMSE on train data = 0.23685939393961208
# R2 on train data = 0.8162744874810608

# %%
predictions_gbt = gbt.transform(test_model)
evaluator_rmse = RegressionEvaluator(labelCol="log_base_fare", predictionCol="prediction", metricName="rmse")
evaluator_r2 = RegressionEvaluator(labelCol="log_base_fare", predictionCol="prediction", metricName="r2")

rmse = evaluator_rmse.evaluate(predictions_gbt)
r2 = evaluator_r2.evaluate(predictions_gbt)

print(f"RMSE on test data = {rmse}")
print(f"R2 on test data = {r2}")
# Out:
# 24/08/23 13:34:53 WARN BasicWriteTaskStatsTracker: Expected 1 files, but only saw 0. This could be due to the output format not writing empty files, or files being not immediately visible in the filesystem.
# 24/08/23 13:34:53 ERROR FileFormatWriter: Aborting job 238ebd14-a351-4125-adea-283fc19b252e.
# java.io.FileNotFoundException: File file:/mnt/c/Users/ADMIN/Desktop/project-1-individual-MaveVu/data/curated/test_pred/_temporary/0 does not exist
# 	at org.apache.hadoop.fs.RawLocalFileSystem.listStatus(RawLocalFileSystem.java:597)
# 	at org.apache.hadoop.fs.FileSystem.listStatus(FileSystem.java:1972)
# 	at org.apache.hadoop.fs.FileSystem.listStatus(FileSystem.java:2014)
# 	at org.apache.hadoop.fs.ChecksumFileSystem.listStatus(ChecksumFileSystem.java:761)
# 	at org.apache.hadoop.fs.FileSystem.listStatus(FileSystem.java:1972)
# 	at org.apache.hadoop.fs.FileSystem.listStatus(FileSystem.java:2014)
# 	at org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter.getAllCommittedTaskPaths(FileOutputCommitter.java:334)
# 	at org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter.commitJobInternal(FileOutputCommitter.java:404)
# 	at org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter.commitJob(FileOutputCommitter.java:377)
# 	at org.apache.parquet.hadoop.ParquetOutputCommitter.commitJob(ParquetOutputCommitter.java:48)
# 	at org.apache.spark.internal.io.HadoopMapReduceCommitProtocol.commitJob(HadoopMapReduceCommitProtocol.scala:192)
# 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.$anonfun$writeAndCommit$3(FileFormatWriter.scala:275)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.timeTakenMs(Utils.scala:552)
# 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.writeAndCommit(FileFormatWriter.scala:275)
# 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.executeWrite(FileFormatWriter.scala:304)
# 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.write(FileFormatWriter.scala:190)
# 	at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand.run(InsertIntoHadoopFsRelationCommand.scala:190)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult$lzycompute(commands.scala:113)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult(commands.scala:111)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.executeCollect(commands.scala:125)
# 	at org.apache.spark.sql.execution.adaptive.AdaptiveSparkPlanExec.$anonfun$executeCollect$1(AdaptiveSparkPlanExec.scala:390)
# 	at org.apache.spark.sql.execution.adaptive.AdaptiveSparkPlanExec.withFinalPlanUpdate(AdaptiveSparkPlanExec.scala:418)
# 	at org.apache.spark.sql.execution.adaptive.AdaptiveSparkPlanExec.executeCollect(AdaptiveSparkPlanExec.scala:390)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.$anonfun$applyOrElse$1(QueryExecution.scala:107)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$6(SQLExecution.scala:125)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:201)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$1(SQLExecution.scala:108)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:900)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:66)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.applyOrElse(QueryExecution.scala:107)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.applyOrElse(QueryExecution.scala:98)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDownWithPruning$1(TreeNode.scala:461)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(origin.scala:76)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDownWithPruning(TreeNode.scala:461)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDownWithPruning(LogicalPlan.scala:32)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning(AnalysisHelper.scala:267)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning$(AnalysisHelper.scala:263)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:32)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:32)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:437)
# 	at org.apache.spark.sql.execution.QueryExecution.eagerlyExecuteCommands(QueryExecution.scala:98)
# 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted$lzycompute(QueryExecution.scala:85)
# 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted(QueryExecution.scala:83)
# 	at org.apache.spark.sql.execution.QueryExecution.assertCommandExecuted(QueryExecution.scala:142)
# 	at org.apache.spark.sql.DataFrameWriter.runCommand(DataFrameWriter.scala:859)
# 	at org.apache.spark.sql.DataFrameWriter.saveToV1Source(DataFrameWriter.scala:388)
# 	at org.apache.spark.sql.DataFrameWriter.saveInternal(DataFrameWriter.scala:361)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:240)
# 	at org.apache.spark.sql.DataFrameWriter.parquet(DataFrameWriter.scala:792)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# 	at java.lang.Thread.run(Thread.java:750)
# [Stage 254:=============================================>         (10 + 2) / 12]
# RMSE on test data = 0.252767076620354
# R2 on test data = 0.806019994823415

# %% [markdown]
# Adding id since spark dataframe does not guarantee the order of rows

# %%
test = test.withColumn('id1', monotonically_increasing_id())
predictions_gbt = predictions_gbt.withColumn('id1', monotonically_increasing_id())
predictions_lm = predictions_lm.withColumn('id1', monotonically_increasing_id())

# %%
predictions_gbt = predictions_gbt.select("id1", "prediction").withColumnRenamed("prediction", "pred_gbt")
predictions_lm = predictions_lm.select("id1", "prediction").withColumnRenamed("prediction", "pred_lm")

# %% [markdown]
# #### Merge the predictions into the dataframe and store it

# %%
sel_test = test.select('date', 'hour', 'pulocationid', 'dolocationid', 'is_weekend', 'trip_miles', 
              'trip_time', 'tolls', 'wnd', 'tmp', 'dew', 'slp', 'base_passenger_fare')
merged_df = sel_test.join(predictions_gbt, 'id1', 'inner') \
                .join(predictions_lm, 'id1', 'inner')

# %%
merged_df \
    .coalesce(1) \
    .write \
    .mode('overwrite') \
    .parquet('../data/curated/test_pred')

# %%
spark.stop()
